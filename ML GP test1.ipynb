# %%
import pandas as pd
data  = pd.read_csv(r"C:\Users\johnd\OneDrive\School\Intro to ML\SP500_ratios1.csv")
data.head()
# Out:
#    permno     adate   qdate  public_date     bm     ps     pcf    dpr    npm  \
# 0   10104  310509.0  301109       310110  0.252  4.976  13.353  0.129  0.250
# 1   10104  310509.0  301109       280210  0.252  5.323  14.285  0.129  0.250
# 2   10104  310509.0  301109       310310  0.252  5.556  14.911  0.129  0.250
# 3   10104  310509.0  280210       300410  0.233  5.381  15.909  0.177  0.234
# 4   10104  310509.0  280210       310510  0.233  4.692  13.871  0.177  0.234
#
#      gpm  ...  dltt_be  debt_assets  debt_capital  de_ratio  cash_ratio  \
# 0  0.822  ...    0.451        0.485         0.338     0.949       1.875
# 1  0.822  ...    0.451        0.485         0.338     0.949       1.875
# 2  0.822  ...    0.451        0.485         0.338     0.949       1.875
# 3  0.816  ...    0.443        0.493         0.346     0.982       1.739
# 4  0.816  ...    0.443        0.493         0.346     0.982       1.739
#
#    quick_ratio  curr_ratio  at_turn    ptb  PEG_trailing
# ...

# %%
# Out:
#   File "<ipython-input-14-92ffe224b921>", line 2
#     signon username=_prompt_;
#                   ^
# SyntaxError: invalid syntax
